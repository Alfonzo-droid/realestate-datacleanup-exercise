# %% [markdown]
# # Limpieza de bienes raíces
#
# Este es un conjunto de datos (dataset) reales que fue descargado usando técnicas de web scraping. La data contiene registros de **Fotocasa**, el cual es uno de los sitios más populares de bienes raíces en España. Por favor no hagas esto (web scraping) a no ser que sea para propósitos académicos.
#
# El dataset fue descargado hace algunos años por Henry Navarro y en ningún caso se obtuvo beneficio económico de ello.
#
# Contiene miles de datos de casas reales publicadas en la web www.fotocasa.com. Tu objetivo es extraer tanta información como sea posible con el conocimiento que tienes hasta ahora de ciencia de datos, por ejemplo ¿cuál es la casa más cara en todo el dataset?
#
# Empecemos precisamente con esa pregunta... ¡Buena suerte!

# %% [markdown]
# #### Ejercicio 00. Lee el dataset assets/real_estate.csv e intenta visualizar la tabla (★☆☆)

# %%
import pandas as pd

# Este archivo CSV contiene puntos y comas en lugar de comas como separadores
ds = pd.read_csv('real_estate.csv', sep=';')
ds
# Out:
#        Unnamed: 0  id_realEstates  isNew                    realEstate_name  \
# 0               1       153771986  False            ferrari 57 inmobiliaria
# 1               2       153867863  False  tecnocasa fuenlabrada ferrocarril
# 2               3       153430440  False                 look find boadilla
# 3               4       152776331  False  tecnocasa fuenlabrada ferrocarril
# 4               5       153180188  False            ferrari 57 inmobiliaria
# ...           ...             ...    ...                                ...
# 15330       15331       153901377  False                infocasa consulting
# 15331       15332       150394373  False                inmobiliaria pulpon
# 15332       15333       153901397  False             tecnocasa torrelodones
# 15333       15334       152607440  False                inmobiliaria pulpon
# 15334       15335       153901356  False                infocasa consulting
#
# ...

# %% [markdown]
# #### Ejercicio 01. ¿Cuál es la casa más cara en todo el dataset? (★☆☆)
#
# Imprime la dirección y el precio de la casa seleccionada. Por ejemplo:
#
# `La casa con dirección en Calle del Prado, Nº20 es la más cara y su precio es de 5000000 USD`

# %%
# TODO

# Encontrar el índice de la fila con el valor máximo en la columna 'price'
precio_caro = ds['price'].idxmax()

# Obtener el nombre de la propiedad correspondiente
direccion_propiedad_mas_cara = ds.loc[precio_caro, 'address']

print("La propiedad mas cara es la que esta ubicada en", direccion_propiedad_mas_cara, "y su valor es de", ds['price'].max() )
# Out:
# La propiedad mas cara es la que esta ubicada en El Escorial y su valor es de 8500000

# %% [markdown]
# #### Ejercicio 02. ¿Cuál es la casa más barata del dataset? (★☆☆)
#
# Imprime la dirección y el precio de la casa seleccionada. Por ejemplo:
#
# `La casa con dirección en Calle Alcalá, Nº58 es la más barata y su precio es de 12000 USD`

# %%
# TODO

# Encontrar el índice de la fila con el valor máximo en la columna 'price'
precio_barato = ds['price'].idxmin()

# Obtener el nombre de la propiedad correspondiente
direccion_propiedad_mas_barata = ds.loc[precio_barato, 'address']

print("La propiedad mas barata es la que esta ubicada en", direccion_propiedad_mas_barata, "y su valor es de", ds['price'].min() )
# Out:
# La propiedad mas barata es la que esta ubicada en Parla y su valor es de 0

# %% [markdown]
# #### Ejercicio 03. ¿Cuál es la casa más grande y la más pequeña del dataset? (★☆☆)
#
# Imprime la dirección y el área de las casas seleccionadas. Por ejemplo:
#
# `La casa más grande está ubicada en Calle Gran Vía, Nº38 y su superficie es de 5000 metros`
#
# `La casa más pequeña está ubicada en Calle Mayor, Nº12 y su superficie es de 200 metros`

# %%
# TODO

# Encontrar el índice de la fila con el valor máximo en la columna 'price'
mas_pequeña = ds['surface'].idxmin()
mas_grande = ds['surface'].idxmax()


# Obtener el nombre de la propiedad correspondiente
direccion_propiedad_mas_pequeña = ds.loc[mas_pequeña, 'address']
direccion_propiedad_mas_grande = ds.loc[mas_grande, 'address']

print("La casa mas pequeña es la que esta ubicada en", direccion_propiedad_mas_pequeña, "y su tamaño es de", ds['surface'].min(),'metros cuadrados' )
print("La casa mas grande es la que esta ubicada en", direccion_propiedad_mas_grande, "y su tamaño es de", ds['surface'].max(), 'metros cuadrados' )
# Out:
# La casa mas pequeña es la que esta ubicada en Calle Amparo,  Madrid Capital y su tamaño es de 15.0 metros cuadrados
# La casa mas grande es la que esta ubicada en Sevilla la Nueva y su tamaño es de 249000.0 metros cuadrados

# %% [markdown]
# #### Ejercicio 04. ¿Cuantas poblaciones (columna level5) contiene el dataset? (★☆☆)
#
# Imprime el nombre de las poblaciones separadas por coma. Por ejemplo:
#
# `> print(populations)`
#
# `population1, population2, population3, ...`

# %%
# TODO

print(','.join(ds['level5']))
# Out:
# Arganda del Rey,Fuenlabrada,Boadilla del Monte,Fuenlabrada,Arganda del Rey,Las Rozas de Madrid,Las Rozas de Madrid,Las Rozas de Madrid,Las Rozas de Madrid, Madrid Capital, Madrid Capital,Villaviciosa de Odón,Pinto,Valdemoro,Navalcarnero, Madrid Capital, Madrid Capital, Madrid Capital,Pozuelo de Alarcón,Torrejón de Ardoz,Navalagamella,San Sebastián de los Reyes, Madrid Capital,Rivas-vaciamadrid,Alpedrete, Madrid Capital, Madrid Capital, Madrid Capital,Móstoles, Madrid Capital, Madrid Capital, Madrid Capital,San Fernando de Henares,Coslada, Madrid Capital,Becerril de la Sierra, Madrid Capital, Madrid Capital, Madrid Capital, Madrid Capital, Madrid Capital, Madrid Capital, Madrid Capital, Madrid Capital, Madrid Capital,Alcalá de Henares, Madrid Capital, Madrid Capital, Madrid Capital, Madrid Capital, Madrid Capital, Madrid Capital, Madrid Capital, Madrid Capital, Madrid Capital, Madrid Capital,Pinto, Madrid Capital, Madrid Capital, Madrid Capital, Madrid Capital, Madrid Capital, Madrid 
# ...

# %% [markdown]
# #### Ejercicio 05. ¿El dataset contiene valores no admitidos (NAs)? (★☆☆)
#
# Imprima un booleano (`True` o `False`) seguido de la fila/columna que contiene el NAs.

# %%
# TODO

ds_booleano = ds.isnull()

print(ds_booleano)
# Out:
#        Unnamed: 0  id_realEstates  isNew  realEstate_name  phone_realEstate  \
# 0           False           False  False            False             False
# 1           False           False  False            False             False
# 2           False           False  False            False             False
# 3           False           False  False            False             False
# 4           False           False  False            False             False
# ...           ...             ...    ...              ...               ...
# 15330       False           False  False            False             False
# 15331       False           False  False            False             False
# 15332       False           False  False            False             False
# 15333       False           False  False            False             False
# 15334       False           False  False            False             False
#
# ...

# %% [markdown]
# #### Ejercicio 06. Elimina los NAs del dataset, si aplica (★★☆)
#
# Imprima una comparación entre las dimensiones del DataFrame original versus el DataFrame después de las eliminaciones.

# %%
# TODO

dsNUEVO = ds.dropna(axis = 1)
print(dsNUEVO)
print('El data set nuevo contiene 12 columnas menos que el original. ')
# Out:
#        Unnamed: 0  id_realEstates  isNew  \
# 0               1       153771986  False
# 1               2       153867863  False
# 2               3       153430440  False
# 3               4       152776331  False
# 4               5       153180188  False
# ...           ...             ...    ...
# 15330       15331       153901377  False
# 15331       15332       150394373  False
# 15332       15333       153901397  False
# 15333       15334       152607440  False
# 15334       15335       153901356  False
#
#                                             url_inmueble   price  \
# 0      https://www.fotocasa.es/es/comprar/vivienda/ma...  195000
# 1      https://www.fotocasa.es/es/comprar/vivienda/ma...   89000
# 2      https://www.fotocasa.es/es/comprar/vivienda/ma...  390000
# 3      https://www.fotocasa.es/es/comprar/vivienda/ma...   89000
# 4      https://www.fotocasa.es/es/comprar/vivienda/ma...  172000
# ...                                                  ...     ...
# ...

# %% [markdown]
# #### Ejercicio 07. ¿Cuál la media de precios en la población (columna level5) de "Arroyomolinos (Madrid)"? (★★☆)
#
# Imprima el valor obtenido.

# %%
# TODO

Filtro_Arroyomolinos = ds['level5'] == 'Arroyomolinos (Madrid)'
precios_Arroyomolinos = ds[Filtro_Arroyomolinos]['price'].mean
()

print('La media de precios en la poblacion Arroyomolinos (Madrid) es de', precios_Arroyomolinos)
# Out:
# La media de precios en la poblacion Arroyomolinos (Madrid) es de <bound method Series.mean of 453      165338
# 607      251646
# 613      396000
# 707      225000
# 852      373000
#           ...
# 15019    218000
# 15089    230000
# 15091    217000
# 15094    227000
# 15192    462000
# Name: price, Length: 137, dtype: int64>

# %% [markdown]
# #### Ejercicio 08. Trazar el histograma de los precios para la población (level5 column) de "Arroyomolinos (Madrid)" y explica qué observas (★★☆)
#
# Imprime el histograma de los precios y escribe en la celda del Markdown un breve análisis del trazado.

# %%
# TODO: Code

import matplotlib.pyplot as plt


plt.hist(ds[Filtro_Arroyomolinos]['price'], bins=20)  # Puedes ajustar el número de bins según tus necesidades
plt.title('Histograma de Precios para la Arremolinos')
plt.xlabel('Precio')
plt.ylabel('Frecuencia')
plt.show()

# %% [markdown]
# **TODO: Markdown**. Se puede observar que la mayoria de las propiedades tienen un pracio que va entre los 200.000 y los 400.000 Con algunas superando ese valor hasta llegar a casi los 600.000

# %% [markdown]
# #### Ejercicio 09. ¿Son los precios promedios de "Valdemorillo" y "Galapagar" los mismos? (★★☆)
#
# Imprime ambos promedios y escribe una conclusión sobre ellos.

# %%
# TODO

Filtro_Valdemorillo = ds['level5'] == 'Valdemorillo'
precios_Valdemorillo = ds[Filtro_Valdemorillo]['price'].mean()

Filtro_Galapagar = ds['level5'] == 'Galapagar'
precios_Galapagar = ds[Filtro_Galapagar]['price'].mean()


print('La media de precios en la poblacion Valdemorillo es de', precios_Valdemorillo)
print('La media de precios en la poblacion Galapagar es de', precios_Galapagar)
print('Se puede observar que en promedio las propiedades de Valdemorillo tienen mayor valor que las de Galapagar, sin embargo son muy simulares')
# Out:
# La media de precios en la poblacion Valdemorillo es de 363860.2931034483
# La media de precios en la poblacion Galapagar es de 360063.20238095237
# Se puede observar que en promedio las propiedades de Valdemorillo tienen mayor valor que las de Galapagar, sin embargo son muy simulares

# %% [markdown]
# #### Ejercicio 10. ¿Son los promedios de precio por metro cuadrado (precio/m2) de "Valdemorillo" y "Galapagar" los mismos? (★★☆)
#
# Imprime ambos promedios de precio por metro cuadrado y escribe una conclusión sobre ellos.
#
# Pista: Crea una nueva columna llamada `pps` (*price per square* o precio por metro cuadrado) y luego analiza los valores.

# %%
# TODO

# Agregar una nueva columna directamente
ds['pps'] = ds['price']/ds['surface']

Filtro_Valdemorillo = ds['level5'] == 'Valdemorillo'
pps_Valdemorillo = ds[Filtro_Valdemorillo]['pps'].mean()

Filtro_Galapagar = ds['level5'] == 'Galapagar'
pps_Galapagar = ds[Filtro_Galapagar]['pps'].mean()

print('La media de precios por metro cuadrado en la poblacion Valdemorillo es de', pps_Valdemorillo)
print('La media de precios por metro cuadrado en la poblacion Galapagar es de', pps_Galapagar)
print('se puede observar que en promedio los precios por metro cuadrado de la poblacion de Galapagar son amyores que los de Valdemorillo')
# Out:
# La media de precios por metro cuadrado en la poblacion Valdemorillo es de 1317.9502109024986
# La media de precios por metro cuadrado en la poblacion Galapagar es de 1606.3240303094024
# se puede observar que en promedio los precios por metro cuadrado de la poblacion de Galapagar son amyores que los de Valdemorillo

# %% [markdown]
# #### Ejercicio 11. Analiza la relación entre la superficie y el precio de las casas. (★★☆)
#
# Pista: Puedes hacer un `scatter plot` y luego escribir una conclusión al respecto.

# %%
# TODO: Código

# Crear el gráfico de dispersión

ds_filtrado = ds[ds['surface'] <= 20000]
plt.scatter(ds_filtrado['surface'], ds_filtrado['price'])

# Agregar títulos y etiquetas a los ejes
plt.title('Relación entre Precio y Superficie')
plt.xlabel('Superficie')
plt.ylabel('Precio')

# Mostrar el gráfico
plt.show()

# %% [markdown]
# **TODO: Markdown**. Se observa un aumento en precio significativo para las propiedades hasta que se acercan a la medida de los 2500 metros cuadrados, una vez pasada esa brecha, las propiedades por encima de ese tamaño parecen tener una disminucion en su valor. Podria estar relacionado a factores como ubicacion, costos de mantenimiento entre otros

# %% [markdown]
# #### Ejercicio 12. ¿Cuántas agencia de bienes raíces contiene el dataset? (★★☆)
#
# Imprime el valor obtenido.

# %%
# TODO

cantidad_de_agencias = ds['realEstate_name'].nunique()

print('El data set contiene un total de', cantidad_de_agencias,'agencias inmobiliarias')
# Out:
# El data set contiene un total de 1821 agencias inmobiliarias

# %% [markdown]
# #### Ejercicio 13. ¿Cuál es la población (columna level5) que contiene la mayor cantidad de casas?(★★☆)
#
# Imprima la población y el número de casas.

# %%
# TODO

moda = ds['level5'].mode()
print('la poblacion con mayor cantidad de casas es', moda)
print(moda)
# Out:
# la poblacion con mayor cantidad de casas es 0     Madrid Capital
# Name: level5, dtype: object
# 0     Madrid Capital
# Name: level5, dtype: object

# %% [markdown]
# #### Ejercicio 14. Ahora vamos a trabajar con el "cinturón sur" de Madrid. Haz un subconjunto del DataFrame original que contenga las siguientes poblaciones (columna level5): "Fuenlabrada", "Leganés", "Getafe", "Alcorcón" (★★☆)
#
# Pista: Filtra el DataFrame original usando la columna `level5` y la función `isin`.

# %%
# TODO

# Crear una lista del cinturon sur a buscar
cinturon_sur = ['Fuenlabrada', 'Leganés', 'Getafe','Alcorcón']

# Filtrar el DataFrame
ds_sur = ds[ds['level5'].isin(cinturon_sur)]
print(ds_sur)
# Out:
#        Unnamed: 0  id_realEstates  isNew  \
# 1               2       153867863  False
# 3               4       152776331  False
# 85             86       153152077  False
# 94             95       153995577  False
# 109           110       153586414  False
# ...           ...             ...    ...
# 15275       15276       153903887  False
# 15291       15292       151697757  False
# 15305       15306       153902389  False
# 15322       15323       153871864  False
# 15325       15326       153901467  False
#
#                                  realEstate_name  phone_realEstate  \
# 1              tecnocasa fuenlabrada ferrocarril       916358736.0
# 3              tecnocasa fuenlabrada ferrocarril       916358736.0
# 85                       sinergical inmobiliaria               NaN
# 94                               viviendas365com       911226014.0
# 109              area uno asesores inmobiliarios       912664081.0
# ...

# %% [markdown]
# #### Ejercicio 15. Traza un gráfico de barras de la mediana de los precios y explica lo que observas (debes usar el subconjunto obtenido del Ejercicio 14) (★★★)
#
# Imprima un gráfico de barras de la mediana de precios y escriba en la celda Markdown un breve análisis sobre el gráfico.

# %%
# TODO: Code


price_zonasur = ds_sur['price'].median()
print(price_zonasur)

Filtro_Fuenlabrada = ds_sur['level5'] == 'Fuenlabrada'
price_Fuenlabrada = ds_sur[Filtro_Fuenlabrada]['price'].median()
print(price_Fuenlabrada)


Filtro_Leganés = ds_sur['level5'] == 'Leganés'
price_Leganés = ds_sur[Filtro_Leganés]['price'].median()
print(price_Leganés)

Filtro_Getafe = ds_sur['level5'] == 'Getafe'
price_Getafe = ds_sur[Filtro_Getafe]['price'].median()
print(price_Getafe)

Filtro_Alcorcón = ds_sur['level5'] == 'Alcorcón'
price_Alcorcón = ds_sur[Filtro_Alcorcón]['price'].median()
print(price_Alcorcón)


#Crear un DataFrame de ejemplo
eje_x = ['General', 'Fuenlabrada', 'Leganés', 'Getafe', 'Alcorcón']

eje_y = [price_zonasur, price_Fuenlabrada, price_Leganés, price_Getafe, price_Alcorcón]

# Crear el gráfico de barras
plt.bar(eje_x, eje_y)
plt.xlabel('Población')
plt.ylabel('Mediana')
plt.title('Medianas por Población')
plt.show()
# Out:
# 175000.0
# 155000.0
# 169950.0
# 285305.0
# 179500.0

# %% [markdown]
# De todo el set la mediana de Getafe parece ser la mayor, por lo que parece la que concentra las propiedades de mayor valor del data set, inversamente la poblacion de Fuenlabrada parece ser la metor.

# %% [markdown]
# #### Ejercicio 16. Calcula la media y la varianza de muestra para las siguientes variables: precio, habitaciones, superficie y baños (debes usar el subconjunto obtenido del Ejercicio 14) (★★★)
#
# Imprime ambos valores por cada variable.

# %%
# TODO

#trabajaremos con las columnas rooms, bathrooms, surface, price
print(ds_sur.columns)

price_zonasurmedia = ds_sur['price'].mean()
price_zonasurvarianza = (ds_sur['price'].std())**2

rooms_zonasurmedia = ds_sur['rooms'].mean()
rooms_zonasurvarianza = (ds_sur['rooms'].std())**2

bathrooms_zonasurmedia = ds_sur['bathrooms'].mean()
bathrooms_zonasurvarianza = (ds_sur['bathrooms'].std())**2

surface_zonasurmedia = ds_sur['surface'].mean()
surface_zonasurvarianza = (ds_sur['surface'].std())**2

print('la media de precios en la zona sur de madrid es', price_zonasurmedia, 'con una varianza de', price_zonasurvarianza)
print('la media de habitaciones en las propieades en la zona sur de madrid es', rooms_zonasurmedia, 'con una varianza de', rooms_zonasurvarianza)
print('la media de baños en las propieades en la zona sur de madrid es', bathrooms_zonasurmedia, 'con una varianza de', bathrooms_zonasurvarianza)
print('la media de metros cuadrados en las propieades en la zona sur de madrid es', surface_zonasurmedia, 'con una varianza de', surface_zonasurvarianza)
# Out:
# Index(['Unnamed: 0', 'id_realEstates', 'isNew', 'realEstate_name',
#        'phone_realEstate', 'url_inmueble', 'rooms', 'bathrooms', 'surface',
#        'price', 'date', 'description', 'address', 'country', 'level1',
#        'level2', 'level3', 'level4', 'level5', 'level6', 'level7', 'level8',
#        'upperLevel', 'countryId', 'level1Id', 'level2Id', 'level3Id',
#        'level4Id', 'level5Id', 'level6Id', 'level7Id', 'level8Id', 'accuracy',
#        'latitude', 'longitude', 'zipCode', 'customZone', 'pps'],
#       dtype='object')
# la media de precios en la zona sur de madrid es 223094.48070562293 con una varianza de 14921367508.04902
# la media de habitaciones en las propieades en la zona sur de madrid es 3.0177383592017737 con una varianza de 0.7188858892927542
# la media de baños en las propieades en la zona sur de madrid es 1.633221850613155 con una varianza de 0.5717968625577321
# ...

# %% [markdown]
# #### Ejercicio 17. ¿Cuál es la casa más cara de cada población? Debes usar el subset obtenido en la pregunta 14 (★★☆)
#
# Imprime tanto la dirección como el precio de la casa seleccionada de cada población. Puedes imprimir un DataFrame o una sola línea para cada población.

# %%
# TODO
price_Fuenlabrada = ds_sur[Filtro_Fuenlabrada]['price'].idxmax()
print(price_Fuenlabrada)


price_Leganés = ds_sur[Filtro_Leganés]['price'].idxmax()
print(price_Leganés)

price_Getafe = ds_sur[Filtro_Getafe]['price'].idxmax()
print(price_Getafe)

price_Alcorcón = ds_sur[Filtro_Alcorcón]['price'].idxmax()
print(price_Alcorcón)

# Obtener el nombre de la propiedad correspondiente
direccion_propiedad_mas_cara_Fuenlabrada = ds_sur.loc[price_Fuenlabrada, 'address']
direccion_propiedad_mas_cara_Leganés = ds_sur.loc[price_Leganés, 'address']
direccion_propiedad_mas_cara_Getafe = ds_sur.loc[price_Getafe, 'address']
direccion_propiedad_mas_cara_Alcorcón = ds_sur.loc[price_Alcorcón, 'address']

print('La casa mas cara en la propiedad de Fuenlabrada esta ubicada en', direccion_propiedad_mas_cara_Fuenlabrada, 'y tiene un valor de', ds_sur[Filtro_Fuenlabrada]['price'].max())
print('La casa mas cara en la propiedad de Leganés esta ubicada en', direccion_propiedad_mas_cara_Leganés, 'y tiene un valor de', ds_sur[Filtro_Leganés]['price'].max())
print('La casa mas cara en la propiedad de Getafe esta ubicada en', direccion_propiedad_mas_cara_Getafe, 'y tiene un valor de', ds_sur[Filtro_Getafe]['price'].max())
print('La casa mas cara en la propiedad de Alcorcón esta ubicada en', direccion_propiedad_mas_cara_Alcorcón, 'y tiene un valor de', ds_sur[Filtro_Alcorcón]['price'].max())
# Out:
# 11561
# 10412
# 2881
# 5585
# La casa mas cara en la propiedad de Fuenlabrada esta ubicada en Calle de Paulo Freire, 5, Fuenlabrada y tiene un valor de 490000
# La casa mas cara en la propiedad de Leganés esta ubicada en Avenida Reina Sofía, Leganés y tiene un valor de 650000
# La casa mas cara en la propiedad de Getafe esta ubicada en Getafe y tiene un valor de 1050000
# La casa mas cara en la propiedad de Alcorcón esta ubicada en Alcorcón y tiene un valor de 950000

# %% [markdown]
# #### Ejercicio 18. Normaliza la variable de precios para cada población y traza los 4 histogramas en el mismo gráfico (debes usar el subconjunto obtenido en la pregunta 14) (★★★)
#
# Para el método de normalización, puedes usar el que consideres adecuado, no hay una única respuesta correcta para esta pregunta. Imprime el gráfico y escribe en la celda de Markdown un breve análisis sobre el gráfico.
#
# Pista: Puedes ayudarte revisando la demostración multihist de Matplotlib.

# %%
# TODO

#USANDO LA NORMALIZACION DE MAXIMOS Y MINIMOS
# Agregar una nueva columna directamente
ds_sur['precio normalizado_Fuenlabrada'] = (ds_sur[Filtro_Fuenlabrada]['price'] - ds_sur[Filtro_Fuenlabrada]['price'].min() )/(ds_sur[Filtro_Fuenlabrada]['price'].max() - ds_sur[Filtro_Fuenlabrada]['price'].min())
ds_sur['precio normalizado_Leganés'] = (ds_sur[Filtro_Leganés]['price'] - ds_sur[Filtro_Leganés]['price'].min() )/(ds_sur[Filtro_Leganés]['price'].max() - ds_sur[Filtro_Leganés]['price'].min())
ds_sur['precio normalizado_Getafe'] = (ds_sur[Filtro_Getafe]['price'] - ds_sur[Filtro_Getafe]['price'].min() )/(ds_sur[Filtro_Getafe]['price'].max() - ds_sur[Filtro_Getafe]['price'].min())
ds_sur['precio normalizado_Alcorcón'] = (ds_sur[Filtro_Alcorcón]['price'] - ds_sur[Filtro_Alcorcón]['price'].min() )/(ds_sur[Filtro_Alcorcón]['price'].max() - ds_sur[Filtro_Alcorcón]['price'].min())


# Crear figura y ejes
fig, ax = plt.subplots()

# Trazar histogramas
ax.hist(ds_sur['precio normalizado_Fuenlabrada'], bins=20, alpha=0.5, label='Fuenlabrada')
ax.hist(ds_sur['precio normalizado_Leganés'], bins=20, alpha=0.5, label='Leganés')
ax.hist(ds_sur['precio normalizado_Getafe'], bins=20, alpha=0.5, label='Getafe')
ax.hist(ds_sur['precio normalizado_Alcorcón'], bins=20, alpha=0.5, label='Alcorcón')

# Personalizar el gráfico
ax.set_xlabel('Propiedades')
ax.set_ylabel('Precio')
ax.set_title('Comparación de Histogramas')
ax.legend()

# Mostrar el gráfico
plt.show()
# Out:
# C:\Users\fonzy\AppData\Local\Temp\ipykernel_20236\3734482796.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ds_sur['precio normalizado_Fuenlabrada'] = (ds_sur[Filtro_Fuenlabrada]['price'] - ds_sur[Filtro_Fuenlabrada]['price'].min() )/(ds_sur[Filtro_Fuenlabrada]['price'].max() - ds_sur[Filtro_Fuenlabrada]['price'].min())
# C:\Users\fonzy\AppData\Local\Temp\ipykernel_20236\3734482796.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# ...

# %% [markdown]
# **TODO: Markdown**. La mayoria de las Propiedades estan por debajo del percentil 50 de los datos, Se observa que en Getafe las propiedades tienden a tener un valor superior.

# %% [markdown]
# #### Ejercicio 19. ¿Qué puedes decir sobre el precio por metro cuadrado (precio/m2) entre los municipios de 'Getafe' y 'Alcorcón'? Debes usar el subconjunto obtenido en la pregunta 14 (★★☆)
#
# Pista: Crea una nueva columna llamada `pps` (price per square en inglés) y luego analiza los valores

# %%
# TODO



pps_Getafemean = ds_sur[Filtro_Getafe]['pps'].mean()
pps_Getafemedian = ds_sur[Filtro_Getafe]['pps'].median()
pps_Getafemax = ds_sur[Filtro_Getafe]['pps'].max()
pps_Getafemin = ds_sur[Filtro_Getafe]['pps'].min()
pps_Getafestd = ds_sur[Filtro_Getafe]['pps'].std()

print('Datos de Getafe para precio por metro cuadrado media',pps_Getafemean,'  mediana ',pps_Getafemedian ,'  minimo',pps_Getafemin, ' maximo' ,pps_Getafemax , '  desviacion estandar',pps_Getafestd )



pps_Alcorcónmean = ds_sur[Filtro_Alcorcón]['pps'].mean()
pps_Alcorcónmedian = ds_sur[Filtro_Alcorcón]['pps'].median()
pps_Alcorcónmax = ds_sur[Filtro_Alcorcón]['pps'].max()
pps_Alcorcónmin = ds_sur[Filtro_Alcorcón]['pps'].min()
pps_Alcorcónstd = ds_sur[Filtro_Alcorcón]['pps'].std()

print('Datos de Alcorcón para precio por metro cuadrado media',pps_Alcorcónmean,'  mediana ',pps_Alcorcónmedian ,'  minimo',pps_Alcorcónmin, ' maximo' ,pps_Alcorcónmax , '  desviacion estandar',pps_Alcorcónstd )
# Out:
# Datos de Getafe para precio por metro cuadrado media 2066.314949251463   mediana  1973.3333333333333   minimo 0.0  maximo 3827.1604938271603   desviacion estandar 741.8727021510158
# Datos de Alcorcón para precio por metro cuadrado media 2239.302480199618   mediana  2207.7922077922076   minimo 604.7619047619048  maximo 3698.159509202454   desviacion estandar 539.9515266064398

# %% [markdown]
# #### Ejercicio 20. Realiza el mismo gráfico para 4 poblaciones diferentes (columna level5) y colócalos en el mismo gráfico. Debes usar el subconjunto obtenido en la pregunta 14 (★★☆)
# Pista: Haz un diagrama de dispersión de cada población usando subgráficos (subplots).

# %%
# TODO

Filtro_Valdemorillo = ds['level5'] == 'Valdemorillo'
Filtro_Arganda_del_Rey = ds['level5'] == 'Arganda del Rey'
Filtro_Boadilla_del_Monte = ds['level5'] == 'Boadilla del Monte'
Filtro_Torrelodones = ds['level5'] == 'Torrelodones'

print(ds['level5'])

ds_sur['precio normalizado_Fuenlabrada'] = (ds_sur[Filtro_Fuenlabrada]['price'] - ds_sur[Filtro_Fuenlabrada]['price'].min() )/(ds_sur[Filtro_Fuenlabrada]['price'].max() - ds_sur[Filtro_Fuenlabrada]['price'].min())
ds_sur['precio normalizado_Leganés'] = (ds_sur[Filtro_Leganés]['price'] - ds_sur[Filtro_Leganés]['price'].min() )/(ds_sur[Filtro_Leganés]['price'].max() - ds_sur[Filtro_Leganés]['price'].min())
ds_sur['precio normalizado_Getafe'] = (ds_sur[Filtro_Getafe]['price'] - ds_sur[Filtro_Getafe]['price'].min() )/(ds_sur[Filtro_Getafe]['price'].max() - ds_sur[Filtro_Getafe]['price'].min())
ds_sur['precio normalizado_Alcorcón'] = (ds_sur[Filtro_Alcorcón]['price'] - ds_sur[Filtro_Alcorcón]['price'].min() )/(ds_sur[Filtro_Alcorcón]['price'].max() - ds_sur[Filtro_Alcorcón]['price'].min())
ds['precio normalizado_Valdemorillo'] = (ds[Filtro_Valdemorillo]['price'] - ds[Filtro_Valdemorillo]['price'].min() )/(ds[Filtro_Valdemorillo]['price'].max() - ds[Filtro_Valdemorillo]['price'].min())
ds['precio normalizado_Arganda del Rey'] = (ds[Filtro_Arganda_del_Rey]['price'] - ds[Filtro_Arganda_del_Rey]['price'].min() )/(ds[Filtro_Arganda_del_Rey]['price'].max() - ds[Filtro_Arganda_del_Rey]['price'].min())
ds['precio normalizado_Boadilla del Monte'] = (ds[Filtro_Boadilla_del_Monte]['price'] - ds[Filtro_Boadilla_del_Monte]['price'].min() )/(ds[Filtro_Boadilla_del_Monte]['price'].max() - ds[Filtro_Boadilla_del_Monte]['price'].min())
ds['precio normalizado_Torrelodones'] = (ds[Filtro_Torrelodones]['price'] - ds[Filtro_Torrelodones]['price'].min() )/(ds[Filtro_Torrelodones]['price'].max() - ds[Filtro_Torrelodones]['price'].min())




# Crear figura y ejes
fig, ax = plt.subplots()

# Trazar histogramas
ax.hist(ds_sur['precio normalizado_Fuenlabrada'], bins=20, alpha=0.5, label='Fuenlabrada')
ax.hist(ds_sur['precio normalizado_Leganés'], bins=20, alpha=0.5, label='Leganés')
ax.hist(ds_sur['precio normalizado_Getafe'], bins=20, alpha=0.5, label='Getafe')
ax.hist(ds_sur['precio normalizado_Alcorcón'], bins=20, alpha=0.5, label='Alcorcón')

ax.hist(ds['precio normalizado_Torrelodones'], bins=20, alpha=0.5, label='Torrelodones')
ax.hist(ds['precio normalizado_Arganda del Rey'], bins=20, alpha=0.5, label='Arganda del Rey')
ax.hist(ds['precio normalizado_Boadilla del Monte'], bins=20, alpha=0.5, label='Boadeilla del Monte')
ax.hist(ds['precio normalizado_Valdemorillo'], bins=20, alpha=0.5, label='Valdemorillo')


# Personalizar el gráfico
ax.set_xlabel('Propiedades')
ax.set_ylabel('Precio')
ax.set_title('Comparación de Histogramas')
ax.legend()

# Mostrar el gráfico
plt.show()

print(ds_sur.columns)
# Out:
# 0               Arganda del Rey
# 1                   Fuenlabrada
# 2            Boadilla del Monte
# 3                   Fuenlabrada
# 4               Arganda del Rey
#                   ...
# 15330            Madrid Capital
# 15331    Velilla de San Antonio
# 15332              Torrelodones
# 15333    Velilla de San Antonio
# 15334            Madrid Capital
# Name: level5, Length: 15335, dtype: object
# C:\Users\fonzy\AppData\Local\Temp\ipykernel_20236\4193415124.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ds_sur['precio normalizado_Fuenlabrada'] = (ds_sur[Filtro_Fuenlabrada]['price'] - ds_sur[Filtro_Fuenlabrada]['price'].min() )/(ds_sur[Filtro_Fuenlabrada]['price'].max() - ds_sur[Filtro_Fuenlabrada]['price'].min())
# ...

# %% [markdown]
# #### Ejercicio 21. Realiza un trazado de las coordenadas (columnas latitud y longitud) del cinturón sur de Madrid por color de cada población (debes usar el subconjunto obtenido del Ejercicio 14) (★★★★)
#
# Ejecuta la siguiente celda y luego comienza a codear en la siguiente. Debes implementar un código simple que transforme las columnas de coordenadas en un diccionario de Python (agrega más información si es necesario) y agrégala al mapa.

# %%
from ipyleaflet import Map, basemaps, Marker

# Mapa centrado en (60 grados latitud y -2.2 grados longitud)
# Latitud, longitud
map = Map(center = (60, -2.2), zoom = 2, min_zoom = 1, max_zoom = 20)
map
# Out:
# Map(center=[60, -2.2], controls=(ZoomControl(options=['position', 'zoom_in_text', 'zoom_in_title', 'zoom_out_t…

# %%
## Aquí: traza la coordenadas de los estados

## PON TU CÓDIGO AQUÍ:

# Usando list comprehension y el método replace()



Filtro_Fuenlabrada = ds_sur['level5'] == 'Fuenlabrada'
latitude_Fuenlabrada = float(ds_sur[Filtro_Fuenlabrada]['latitude'].mean())
longitude_Fuenlabrada = float(ds_sur[Filtro_Fuenlabrada]['longitude'].mean())



Filtro_Leganés = ds_sur['level5'] == 'Leganés'
latitude_Leganés = float(ds_sur[Filtro_Leganés]['latitude'].mean())
longitude_Leganés = float(ds_sur[Filtro_Leganés]['longitude'].mean())



Filtro_Getafe = ds_sur['level5'] == 'Getafe'
latitude_Getafe = float(ds_sur[Filtro_Getafe]['latitude'].mean())
longitude_Getafe = float(ds_sur[Filtro_Getafe]['longitude'].mean())


Filtro_Alcorcón = ds_sur['level5'] == 'Alcorcón'
latitude_Alcorcón = float(ds_sur[Filtro_Alcorcón]['latitude'].mean())
longitude_Alcorcón = float(ds_sur[Filtro_Alcorcón]['longitude'].mean())

ds_cinturonsur = {
    'latitude': [latitude_Alcorcón, latitude_Fuenlabrada, latitude_Getafe, latitude_Leganés],
    'longitude': [longitude_Alcorcón, longitude_Fuenlabrada, longitude_Getafe, longitude_Leganés]
}



# Agregar marcadores
for lat, lon in zip(ds_cinturonsur['latitude'], ds_cinturonsur['longitude']):
    marker = Marker(location=[lat, lon])
    map.add_layer(marker)
